# %% [markdown]
# ![RISE MICCAI LOGO](https://summer.rise-miccai.org/resources/images/logo.png)

# %% [markdown]
# # 👋 Welcome to the RISE-MICCAI Summer School!
#
# We're excited to have you here! In this notebook, you will explore how to work with real chest X-ray data, apply essential preprocessing steps, and prepare the images for machine learning.
#
# **If You’re Using Google Colab (Recommended)** <br>
# Google Colab lets you run this notebook in the cloud, with free access to GPUs , no installation required! To get started: Run each code cell using Shift + Enter or by clicking the ▶️ play button on the left.
#
#
# **If You Prefer to Run Locally** <br>
# You will need to create a Python environment and install the required libraries.
#
# Step 1: Create a virtual environment (choose one)
#
# - Using conda:
#
# ```conda create -n medical-ai python=3.8``` <br>
# ```conda activate medical-ai```
#
# - Using venv (built-in):
#
# ```python3 -m venv medical-ai``` <br>
# ```source medical-ai/bin/activate  # or .\medical-ai\Scripts\activate on Windows```
#
# Step 2: Install the required packages <br>
# ```pip install pydicom albumentations opencv-python scikit-image matplotlib pandas torch torchvision```
#
#
# Let’s get started 🚀
#
# ---

# %%
'''Install required packages for the Day 1 Preprocessing notebook.'''

# !pip install pydicom albumentations opencv-python scikit-image matplotlib pandas torch torchvision
# Out:
# Collecting pydicom
#   Downloading pydicom-3.0.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.11/dist-packages (2.0.8)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.11/dist-packages (from albumentations) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from albumentations) (1.15.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from albumentations) (2.11.7)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.11/dist-packages (from albumentations) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentations) (4.12.0.88)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.24->albumentations) (3.12.5)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.24->albumentations) (6.5.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (3.5)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (11.2.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2025.6.11)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9.2->albumentations) (0.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading pydicom-3.0.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 33.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 84.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.8 MB/s eta 0:00:00
# Installing collected packages: pydicom, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pydicom-3.0.1

# %%
'''Download the MIMIC-CXR dataset subset for the summer school.'''

# !wget https://mbzuaiac-my.sharepoint.com/:x:/g/personal/shahad_hardan_mbzuai_ac_ae/ETfcvc6fJplIhJQ1QtGO6GgBGRz2pwL3ue-tf90q8uxQtQ?download=1 -O mimic-cxr-subset.csv

# !wget https://mbzuaiac-my.sharepoint.com/:u:/g/personal/shahad_hardan_mbzuai_ac_ae/EYhR36CHGUhFoZRD3tGYLU8B65IKnQe_uSx1LM9WTiDFRQ?download=1 -O mimic-cxr.zip mimic-cxr-subset-summer-school.zip

'''Unzip the downloaded zip file. '''

# !unzip mimic-cxr.zip -d mimic-cxr-subset-summer-school
# Out:
# --2025-07-14 10:44:30--  https://mbzuaiac-my.sharepoint.com/:x:/g/personal/shahad_hardan_mbzuai_ac_ae/ETfcvc6fJplIhJQ1QtGO6GgBGRz2pwL3ue-tf90q8uxQtQ?download=1
# Resolving mbzuaiac-my.sharepoint.com (mbzuaiac-my.sharepoint.com)... 52.107.248.40, 52.107.248.76, 52.107.248.71, ...
# Connecting to mbzuaiac-my.sharepoint.com (mbzuaiac-my.sharepoint.com)|52.107.248.40|:443... connected.
# HTTP request sent, awaiting response... 302
# Location: /personal/shahad_hardan_mbzuai_ac_ae/Documents/Summer%20School%20-%20MICCAI/MIMIC-CXR/mimic-cxr-subset.csv?ga=1 [following]
# --2025-07-14 10:44:31--  https://mbzuaiac-my.sharepoint.com/personal/shahad_hardan_mbzuai_ac_ae/Documents/Summer%20School%20-%20MICCAI/MIMIC-CXR/mimic-cxr-subset.csv?ga=1
# Reusing existing connection to mbzuaiac-my.sharepoint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 40531 (40K) [application/octet-stream]
# Saving to: ‘mimic-cxr-subset.csv’
#
# mimic-cxr-subset.cs 100%[===================>]  39.58K   161KB/s    in 0.2s
#
# 2025-07-14 10:44:32 (161 KB/s) - ‘mimic-cxr-subset.csv’ saved [40531/40531]
#
# --2025-07-14 10:44:32--  https://mbzuaiac-my.sharepoint.com/:u:/g/personal/shahad_hardan_mbzuai_ac_ae/EYhR36CHGUhFoZRD3tGYLU8B65IKnQe_uSx1LM9WTiDFRQ?download=1
# Resolving mbzuaiac-my.sharepoint.com (mbzuaiac-my.sharepoint.com)... 52.107.248.40, 52.107.248.76, 52.107.248.71, ...
# Connecting to mbzuaiac-my.sharepoint.com (mbzuaiac-my.sharepoint.com)|52.107.248.40|:443... connected.
# HTTP request sent, awaiting response... 302
# Location: /personal/shahad_hardan_mbzuai_ac_ae/Documents/Summer%20School%20-%20MICCAI/MIMIC-CXR/mimic-cxr-subset-summer-school.zip?ga=1 [following]
# --2025-07-14 10:44:33--  https://mbzuaiac-my.sharepoint.com/personal/shahad_hardan_mbzuai_ac_ae/Documents/Summer%20School%20-%20MICCAI/MIMIC-CXR/mimic-cxr-subset-summer-school.zip?ga=1
# Reusing existing connection to mbzuaiac-my.sharepoint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4937327311 (4.6G) [application/x-zip-compressed]
# Saving to: ‘mimic-cxr.zip’
#
# mimic-cxr.zip       100%[===================>]   4.60G  39.5MB/s    in 2m 6s
#
# 2025-07-14 10:46:39 (37.4 MB/s) - ‘mimic-cxr.zip’ saved [4937327311/4937327311]
#
# --2025-07-14 10:46:39--  http://mimic-cxr-subset-summer-school.zip/
# Resolving mimic-cxr-subset-summer-school.zip (mimic-cxr-subset-summer-school.zip)... failed: Name or service not known.
# wget: unable to resolve host address ‘mimic-cxr-subset-summer-school.zip’
# FINISHED --2025-07-14 10:46:39--
# Total wall clock time: 2m 7s
# Downloaded: 1 files, 4.6G in 2m 6s (37.4 MB/s)
# Archive:  mimic-cxr.zip
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19754677/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19911542/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19289869/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19993776/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19296504/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19818004/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19571384/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19263653/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19717260/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19658009/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19281994/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19348515/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19510025/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19212152/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19017172/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19275656/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19769933/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19890872/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19462352/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19062760/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19931942/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19696084/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19957730/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19765159/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19030295/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19263269/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19856485/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19453133/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19159928/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19897794/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19618919/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19044308/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19601805/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19645833/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19857858/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19527260/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p19/p19509569/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17854225/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17290566/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17711692/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17137002/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17248632/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17805562/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17458909/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17245945/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17421190/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17724257/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17967857/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17627721/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17038863/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17736320/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17081089/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17052080/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17191670/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17315623/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17167392/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17550708/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17361324/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17551936/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17515818/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17399295/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17506285/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17600369/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17025050/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17527480/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17783442/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17848200/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17786366/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17257123/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17566649/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17145854/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17851173/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p17/p17533683/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10757032/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10286475/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10899766/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10892316/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10037598/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10236661/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10851836/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10130348/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10420050/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10253803/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10792610/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10887781/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10546797/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10553084/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10914903/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10039360/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10429567/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10028480/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10228186/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10251182/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10254837/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10592564/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10761861/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10684247/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10624517/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10277901/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10040025/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10640977/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10388429/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10576063/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10336412/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10313763/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10634612/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10874692/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10194132/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10490475/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10302201/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10839265/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10773491/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10152675/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10674538/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10912224/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10317265/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10098993/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10432951/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10533101/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10968253/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10367989/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10940805/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10607527/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10692735/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10949720/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10336114/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10866278/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10352433/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10849254/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10417458/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10154271/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10629866/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10607737/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10532466/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10773964/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10170334/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10850680/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10834132/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10422699/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10763687/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p10/p10718572/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11722967/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11751604/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11812923/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11404276/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11427894/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11873714/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11840969/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11004477/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11045286/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11763361/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11563009/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11364345/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11878216/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11444270/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11244926/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11594544/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11920847/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11681682/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11354492/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11912778/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11256275/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11762732/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11407341/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11967908/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11625397/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11696880/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11763662/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11459376/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11961238/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11010572/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11615169/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11456797/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11919347/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11198300/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11247575/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11628624/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11344751/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11008891/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11141118/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11795801/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11557618/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11394517/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11154055/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11474179/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11544655/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11623772/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11660627/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11282384/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11801365/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11206247/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11121223/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11365860/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11539240/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11422321/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11696577/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11433898/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11053589/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11978101/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11564354/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11242848/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11845306/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11977522/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11440245/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11898077/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11919942/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11688185/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11169490/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11826223/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11392990/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11113889/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11086980/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11126593/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11894213/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11133211/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11153132/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11148580/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11451232/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11585967/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11378369/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11576703/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11390987/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11321997/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11779216/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p11/p11482036/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16734287/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16639614/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16597631/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16108772/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16607719/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16538543/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16419110/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16750550/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16222235/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16131803/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16296993/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16299919/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16386591/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16646862/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16057879/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16803132/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16803709/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16152824/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16277550/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16521756/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16422436/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16174132/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16921793/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16949275/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16293344/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16307595/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16366195/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16223079/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16743676/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16724925/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16278052/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16700861/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16319384/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16952127/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16306505/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16472270/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16943846/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16523531/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16516882/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16409112/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16912501/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16003391/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16108064/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16805260/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16435858/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16674342/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16692460/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16843636/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16760209/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16226904/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16168308/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16207902/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16959552/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16557606/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16712364/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16712399/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p16/p16935843/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18530753/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18904533/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18757167/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18783149/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18531331/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18900479/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18672842/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18940953/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18410503/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18854049/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18622135/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18868417/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18314104/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18376342/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18843419/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18853045/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18348848/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18693623/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18360532/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18718424/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18279197/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18335908/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18521233/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18441895/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18011775/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18568013/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18135242/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18048304/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18313642/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18396451/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18837747/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18103600/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18581055/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18305899/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18527006/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18333592/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18947160/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18765708/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18154666/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18532084/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18456681/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18118373/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18962557/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18712920/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18424207/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18116283/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p18/p18189739/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13511876/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13474359/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13067742/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13211467/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13852030/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13718494/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13942292/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13625172/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13374841/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13961236/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13096970/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13826828/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13005295/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13060436/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13798658/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13912990/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13104348/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13871299/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13610194/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13930547/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13537167/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13388171/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13669110/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13524796/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13332932/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13083369/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13361603/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13455616/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13723709/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13194187/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13791337/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13690559/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13959042/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13807179/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13696494/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13165812/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13022039/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13724584/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13663336/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13860063/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13310560/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13595028/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13471464/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13108527/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13877335/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13723259/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p13/p13025726/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14927306/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14851458/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14520921/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14186978/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14480845/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14462566/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14774414/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14003369/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14861926/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14108608/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14815004/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14643163/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14395567/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14733367/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14780475/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14485204/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14840575/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14056083/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14871009/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14666983/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14717859/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14295375/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14896868/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14215681/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14995538/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14610106/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14838068/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14774360/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14504982/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14062965/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14566882/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14984395/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14160981/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14148978/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14271401/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14365589/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14718940/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14362539/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14964071/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14511845/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14617353/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p14/p14555308/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15621186/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15097014/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15003327/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15892758/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15526064/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15856008/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15101217/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15390338/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15294269/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15866889/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15782217/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15424808/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15587897/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15521468/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15611821/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15276693/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15018114/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15713148/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15046768/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15103284/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15999089/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15292682/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15172072/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15332062/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15341985/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15884459/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15143186/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15081052/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15975193/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15312163/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15682570/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15038651/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15087570/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15313897/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15280004/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15898132/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15743778/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15877959/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15459380/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15812823/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15306238/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15497465/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12706696/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12020348/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12662051/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12433158/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12779994/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12604446/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12070454/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12950787/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12654952/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12544547/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12002285/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12537643/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12960546/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12427592/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12759241/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12843938/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12136017/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12110985/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12740948/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12206478/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12992793/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12307889/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12625430/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12415393/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12681303/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12218235/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12343483/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12043836/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12279260/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12615749/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12405224/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12639945/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12995867/
#    creating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12515935/
# ...
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15866889/s59089387/e244ab0f-f1b6c5b3-84990d8c-ccd9148e-4f066892.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15782217/s53495611/f04b0902-53c5aa99-c1e875c6-8ccc7a04-330d03a7.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15424808/s54536444/ed73f920-fabbc668-7f91f355-2a4f5eda-83c0c139.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15587897/s56456348/897d6c0d-91abb6b0-69c79e05-fd4d2b55-041ddfb6.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15521468/s57652374/9c9d774f-5fbf6a29-db6a455f-c8247bb0-b402e2b7.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15611821/s52936495/1e7563d9-2e619bb2-c5283463-58fbebbf-01b180e8.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15276693/s59418962/26c5555a-e9940ce8-f14ed084-9255f4c1-b2c6c516.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15018114/s56922699/0739858b-93fcdf6d-ddcd521b-614f36a3-532cd335.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15713148/s53253561/d0ad933b-0ff0fa4f-bd6b669d-a0931003-7ea00aab.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15046768/s50340672/e0104303-430cdfae-5848a171-34c9bb07-b006fd0a.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15103284/s51963159/f55d3052-2f0bd785-32079f93-1dc01690-2ac51552.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15999089/s50872325/37069689-f6f08115-5cad1248-3b96a966-0fd4dceb.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15292682/s58609964/164e2ff0-c6468822-16bc7399-fcad73a2-e2420936.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15172072/s50658985/88fa6549-e68095e2-202899c5-5194cc48-de99c9da.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15332062/s51566922/0a05842d-9c8880ab-31862827-3f511661-5e1ab3b6.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15341985/s58433898/f7bd6be6-d4e852af-7ef58d81-664a0e95-34d08550.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15884459/s58072648/1a589d19-a19a2ff8-925036d6-48a95d5f-1a97c863.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15143186/s50900904/80ff2749-ef33c2f2-d427a6e0-fd7af72f-ab3908ab.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15081052/s54062997/6ff01e4a-b6b5b57a-2c3850ed-700e5222-ea48deb9.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15975193/s59960062/2f2af440-8fececbe-8c086bbc-5256b9b9-1936cbee.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15312163/s55752073/62e4f590-83e27b20-e8700873-454f9227-54e6262a.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15682570/s58470428/38c869b3-e6d0ceb0-25c0587b-a4f8917a-fbf824ec.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15038651/s53658160/928beed8-c7ca0ea7-859f96be-58288a74-ccc8b244.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15087570/s52343262/4be8cb14-736b2a86-f8c42df1-95ca5551-bf3b0e45.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15313897/s54937644/4253eb6e-20996ae4-d2394bf6-775ea5c1-e3f93300.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15280004/s58288301/eb0ec7f2-a03fcbe6-9e15bebc-19ec3972-9b6f1ecf.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15898132/s58961864/9ea76266-78da15e3-02813a3e-189a8f1a-bdbee85a.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15743778/s53204988/10ff41e5-86093393-1c873fab-c43e9a8c-1da5fba1.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15877959/s57753204/06770d25-2490186a-75a86bd2-909b2526-3680d59d.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15459380/s55365276/6534b82a-b2f12dff-33857c0f-526e2cd2-7cf8d09b.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15812823/s51070607/92235d79-3bb8a378-f503c66c-9b8c3d7a-c7d42926.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15306238/s57813656/7d8bf03b-8e677b77-d6b25a7f-76bfcef0-bb22169b.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p15/p15497465/s58856482/28caae52-bec9f01e-0cd6e5fa-bba186e2-40a0e6f8.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12706696/s59973058/860c7ccf-48a733d6-0a07dc67-efd97ec5-5b42f9dc.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12020348/s51583673/2352cd55-d1d6e0ac-aab74263-cccc0ab3-de9865b0.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12662051/s55469059/612b9a8a-074714af-a62f5a7e-46a4d7dd-fb1969e4.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12433158/s57961493/b4890de8-bb3d1ec1-a8338e78-a32c19e4-32d7bcf4.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12779994/s52845006/da60779c-13bc3986-640c61a8-d0d2f6d7-b938f826.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12604446/s59685494/dd3a8464-cdd97dd6-64ff83d2-95e0b464-cd22de3e.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12070454/s56390965/7f424517-142a00f1-fb3a97fc-26480572-0cd74f06.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12950787/s59148144/e0907ce4-55d4b362-de79c7de-fa460629-bd690197.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12654952/s54688607/30ca39a3-1c22f563-dceb645c-51065daf-ff2db79b.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12544547/s54742210/a16a8f29-48226bd8-06d4e80a-d4dde42f-92ad2383.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12002285/s51668897/addd05d0-11be1f0f-c7502029-5002e3ce-d7763ed7.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12002285/s59990886/45529c3f-4dd07536-094991f9-37894f13-5ac02bb9.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12537643/s52673941/ee24b37a-35691be8-368d15e5-2af35dac-281301de.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12960546/s50239274/3cd9e0ed-5828829c-3f7d5d55-c964c087-9935d1c8.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12427592/s50819505/02326b75-ef42801d-d8846d1c-9760461d-b4365d0e.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12759241/s56767164/88a72cec-eda3d5f1-d1f2d33f-d1efb9b0-4e492022.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12843938/s50253911/18f65381-b889a00b-6d1eba00-7aafe028-3e4f4e43.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12136017/s54340857/8680a777-5264e774-b378574d-eb230d31-41cce775.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12110985/s52775712/9d01f965-a760842f-a8ab1614-7cbb48be-dddd6341.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12740948/s52809686/21ad7b45-5ca7cebf-b3337891-85008a57-3fdb82fe.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12206478/s51235156/c3d23b4b-5a4ad8f2-f1a1df36-af5cdc1f-f2c45b25.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12992793/s55546903/c53ad5b5-c08e1f09-25225a4e-4382c1fc-04ec73e9.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12307889/s57726280/dc0ad069-62a67d87-41790328-8891c9d6-046b02da.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12625430/s55891642/49ec1ac3-ebf2025b-d9455c25-21ffa9e4-92955aed.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12625430/s56143145/47cfd5c9-58f8f898-518032ec-171c6d13-5fe379b7.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12415393/s50214586/08448992-4fad14a8-95ea1245-7f67b5e7-5408480d.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12681303/s58291852/2dd4c14b-928d638e-7373c7a5-90711748-293263eb.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12218235/s52535865/f9f829ef-8e3f64ff-8c0c539e-027e8713-5b496de6.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12343483/s56608089/ce9efb3d-2747b512-c936e997-1e4b179f-0b8d2bf6.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12043836/s52563617/d1bfbbd0-cee53b75-0c83bc1e-bc6debca-14ed4935.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12279260/s57385955/5301a713-14eb8a0f-7b75b668-7380ff5a-e0625730.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12615749/s51184223/d67fdfb7-f9493ee9-fdf2e8a5-7ed0f7b0-7bbe288a.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12615749/s56191438/7d4038fd-a535f030-c35a292f-acd02221-f1ba5838.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12405224/s54043623/38b32c11-d57d9ee5-0cd59a19-4cfbd282-0cbcdc44.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12405224/s54043623/346ea542-35a25eba-c29f4f82-53f81838-29691b81.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12639945/s51274524/22f2aff8-e7bffab1-6ad628b7-72e1b88e-67c5f3cc.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12995867/s54694807/95adeb4b-e940fba6-458c5da2-3c3183f0-5ee010b5.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12515935/s52685029/a8e2abf1-a4122caa-4a35eb5f-17e0b598-e3a1b1ae.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12079903/s58687507/e7f907c6-71bd8db8-e22ce864-27d786cd-e69b3c1c.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12330397/s58002831/a55a8a94-5621439d-f05eff80-da27bf0d-69e2a935.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12152816/s57441659/9e560382-436cf924-43f75054-3c66e1bc-b8a3f06e.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12612379/s58734376/5c3f277a-b4a2fd6b-c2849ed1-455f3365-8cd424b1.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12559662/s50607742/b536cf02-77a8e4b5-388a1d74-fb78bfdd-900d147b.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12735506/s55314057/750ce901-e3fc195b-10599aed-900ebef0-848bf6a1.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12735506/s57227081/91fb420a-7dd6a077-be10a82c-9a8f7928-d186e917.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12199702/s56575847/d800100e-3c9881c1-749eb770-e1011921-222f1146.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12199702/s55768850/4d36518d-8c021de1-4015d68b-cd6bcca9-fed1f935.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12032964/s55321887/240307d2-50f9615b-f117a830-58c87454-21761fe3.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12028465/s58377719/1fb8a4d9-fa7b3fb5-03e3b028-46c8cedf-a4e33ddd.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12027688/s54768458/d9b72f37-cc85588e-d7b1785a-1c384fff-d56da23e.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12577612/s54460868/67f42aac-244509d7-f28bbb1e-92bc0f68-bb2d9f75.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12645992/s54300494/c2e81034-89175728-85aeeae0-23d24a50-b0587921.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12704088/s57609966/1db572a4-51c54557-2fd5095d-47692ca8-b82773cc.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12456824/s50050827/4f064b7f-8b900b1e-ef5d7060-2444fa61-5d266c26.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12019930/s54406761/deed11c6-cebef128-ecacfb52-58dd441f-bd52bc72.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12248852/s54931364/a7269bd6-5e78c16f-41eeb67e-337ef157-7649f87c.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12729521/s53017254/e04f3597-e6cdfe8d-68111116-ad5c5cfd-30ac5867.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12729521/s50579837/431a3b80-d914d0cc-37e3bee6-6f38f432-7b3a5f3a.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12727273/s57737821/cdc87e5f-baf41e3d-35c55f63-627d6379-585c04fc.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12679947/s58977593/12470f9f-66cb3e70-db22efcb-26beda1d-e564d8f7.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12852433/s52334317/cb81b540-dc03ddb5-b87b4bdf-d5400aef-a6a78d27.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12745380/s57975197/83310773-90e87a49-37d0e876-cdcdba77-0812881b.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12745380/s55893275/e1c6c446-d3785131-5facfd90-21f096c8-3a28844f.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12220452/s57986362/00bdf2bf-65b32748-a7ee0f95-e6e8fb70-e84746d9.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12838969/s54934338/e4464b30-6f634812-cb50a41f-cea55249-4a6e0fb1.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12764402/s54064800/081e279e-b0923a53-2c04878a-f759b071-2c0e1da9.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12764402/s54064800/8f52c156-7407bf97-ec66fc0e-141c5c9a-e4e06074.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12669453/s54601827/388174c0-792584bd-d0c17d5c-db895d29-c0928feb.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12039448/s52825198/b0487686-c702ade4-bfa9453a-844b9665-4c9a3a4a.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12039448/s59825919/4407d05e-5b66beb6-9081025c-d25a46de-ffd1ada3.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12903459/s50962563/9d32f197-fcf3cb99-8478279d-294a6185-c2f0cd41.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12185260/s58039633/bb1bfdd1-1f7ffe8b-398758a1-220caec9-244f7274.dcm
#   inflating: mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/p12/p12106117/s50953738/2fe05bbb-2d5e41e7-21b6de6c-79dc830c-9dc02804.dcm

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pydicom
import numpy as np
import os
import albumentations as A
from albumentations.pytorch import ToTensorV2

# %% [markdown]
# The **`pydicom`** library is a Python package for **reading, modifying, and writing DICOM files** – which are the standard format for storing medical imaging data (like X-rays, CTs, MRIs).
#
# ---
#
# ### 🧠 What is DICOM?
#
# DICOM = **Digital Imaging and Communications in Medicine**
#
# It stores:
#
# * **Image data** (e.g. 512×512 grayscale pixels)
# * **Metadata** like:
#
#   * Patient name, age, sex
#   * Modality (CT, MR, X-ray)
#   * Study date/time
#   * Diagnosis notes
#   * Equipment info
#
# ---
#
# ### ✅ What `pydicom` lets you do:
#
# | Task                  | Example                                         |
# | --------------------- | ----------------------------------------------- |
# | Load a DICOM file     | `ds = pydicom.dcmread("image.dcm")`             |
# | Access metadata       | `ds.PatientName`, `ds.StudyDate`, `ds.Modality` |
# | View the image        | `image = ds.pixel_array`                        |
# | Modify metadata       | `ds.PatientName = "Anonymous"`                  |
# | Save a modified DICOM | `ds.save_as("new_image.dcm")`                   |
#
# ---
#
# ### 🔧 Example: Load and display a DICOM image
#
# ```python
# import pydicom
# import matplotlib.pyplot as plt
#
# # Load the file
# ds = pydicom.dcmread("sample.dcm")
#
# # Get image data
# img = ds.pixel_array
#
# # Display the image
# plt.imshow(img, cmap='gray')
# plt.title(f"Patient: {ds.PatientName}")
# plt.axis('off')
# plt.show()
# ```
#
# ---
#
# ### 🔍 Useful Attributes
#
# ```python
# ds.PatientName
# ds.Modality            # CT, MR, CR, etc.
# ds.StudyDate
# ds.Rows, ds.Columns    # Image dimensions
# ds.PhotometricInterpretation  # MONOCHROME1 or MONOCHROME2
# ```
#
# ---
#
# ### 📦 Install
#
# ```bash
# pip install pydicom
# ```
#
# ---
#
# ### 🚫 What pydicom doesn't do:
#
# * It **doesn’t handle image windowing/scaling** automatically.
# * It **doesn’t anonymize or encrypt** DICOMs by default (but you can write tools with it).
# * It doesn’t do **3D rendering or advanced viewing** – use it with tools like `SimpleITK`, `nibabel`, or `vtk` for those.

# %% [markdown]
# This line of code is importing the **Albumentations** library and its PyTorch integration:
#
# ---
#
# # 🔍 What is Albumentations?
#
# **Albumentations** is a **fast, flexible, and easy-to-use image augmentation library**. It's especially useful for training deep learning models on images, particularly in computer vision tasks.
#
# ---
#
# ### 📦 Code Explanation:
#
# ```python
# import albumentations as A
# ```
#
# * Imports Albumentations using alias `A` (common convention).
# * You can now access augmentations like `A.HorizontalFlip()`, `A.RandomBrightnessContrast()`, etc.
#
# ---
#
# ```python
# from albumentations.pytorch import ToTensorV2
# ```
#
# * Imports the **`ToTensorV2`** transformation.
# * It converts a NumPy image (from OpenCV-style `H x W x C`) into a **PyTorch tensor** (`C x H x W`) and also **normalizes pixel values to \[0, 1]** if they were `uint8`.
#
# ---
#
# ### ✅ Example Usage:
#
# ```python
# transform = A.Compose([
#     A.Resize(224, 224),
#     A.HorizontalFlip(p=0.5),
#     A.RandomBrightnessContrast(p=0.2),
#     A.Normalize(mean=(0.5,), std=(0.5,)),  # Normalize pixel values
#     ToTensorV2()  # Convert to PyTorch tensor
# ])
# ```
#
# You would then apply this to your image before feeding it to a neural network.
#
# ---
#
# ### 🧠 Why use Albumentations?
#
# * Fast (uses OpenCV under the hood)
# * Works with bounding boxes, masks, and keypoints
# * Easy to compose and randomize multiple augmentations
#
# Let me know if you want help writing a transformation pipeline for your dataset!

# %% [markdown]
# # Medical Imaging Preprocessing and Data Handling
#
# Preprocessing is a crucial step in medical imaging pipelines that ensures data consistency, enhances image quality, and removes irrelevant variations. When medical images come from hospitals, their raw format might include artifacts, either because of the acquistion machines or the human intervention. In this notebook, you willl explore how preprocessing transforms raw chest X-ray images into a standardized format suitable for building reliable AI models. We will use a subset of the MIMIC-CXR dataset.
#
#
# ## MIMIC - CXR Dataset
#
# Introduction: MIMIC-CXR is a large public dataset of chest X-rays collected from real hospital patients at Beth Israel Deaconess Medical Center. It includes both frontal and lateral chest images, paired with clinical notes and metadata. In this notebook, we focus on a subset of frontal images labeled with pulmonary edema severity for machine learning tasks. The dataset has four classes of patients having 1) no edema, 2) vascular congestion, 3) interstitial edema, and 4) alveolar edema.
#
# Reference: https://physionet.org/content/mimic-cxr/2.1.0/
#
# By the end of this notebook, you will:
#
# - Understand the structure of medical imaging datasets like MIMIC-CXR.
# - Load and visualize DICOM chest X-ray images.
# - Apply image preprocessing steps like intensity clipping, resizing, and normalization.
# - Implement data augmentation to improve generalization.
# - Build a custom PyTorch Dataset for model training.
# - Explore traditional feature extraction methods like ORB and GLCM.
# - Learn how preprocessing and features affect downstream AI models in healthcare.

# %% [markdown]
# ## Task 1: Understanding the Data Structure

# %%
# Load the CSV file
MIMIC_CXR_METADATA_PATH = './mimic-cxr-subset.csv'
df = pd.read_csv(MIMIC_CXR_METADATA_PATH)

# Show the first few rows
df.head()
# Out:
#    subject_id  study_id                                      dicom_id  \
# 0    10039360  53999249  6b2e134c-da7d94d2-61b74f39-a0149009-edcd3e02
# 1    10130348  57511959  c23640ba-9a3fc83e-df6f06f2-9244d819-275ef0b3
# 2    10154271  51768020  c92820ab-86ca072a-cb979fed-e8a9b8f0-2e1b4472
# 3    10170334  50465091  41eb4980-c532d3f5-25e1b923-6696c9fa-b9e26262
# 4    10228186  57118202  621d8f8d-5a467b27-77152e93-31311462-b5921953
#
#    edema_severity fold
# 0               1    3
# 1               0    1
# 2               1    2
# 3               0    3
# 4               0    5

# %%
print(df.shape )
print("so there is 600 records and 5 columns(features)")
# Out:
# (600, 5)
# so there is 600 records and 5 columns(features)

# %%
df.columns
# Out:
# Index(['subject_id', 'study_id', 'dicom_id', 'edema_severity', 'fold'], dtype='object')

# %%
df.describe()
# Out:
#          subject_id      study_id  edema_severity
# count  6.000000e+02  6.000000e+02      600.000000
# mean   1.399538e+07  5.498883e+07        1.015000
# std    2.930759e+06  2.827623e+06        1.031123
# min    1.002848e+07  5.005083e+07        0.000000
# 25%    1.143240e+07  5.252150e+07        0.000000
# 50%    1.310644e+07  5.493599e+07        1.000000
# 75%    1.648342e+07  5.743091e+07        2.000000
# max    1.999378e+07  5.999089e+07        3.000000

# %% [markdown]
# As you can see in the dataset below, it includes dicom_id of patients, but what are DICOM images?
#
# The Digital Imaging and Communications in Medicine (DICOM) Standard specifies a non-proprietary data interchange protocol, digital image format, and file structure for biomedical images and image-related information.
#
# DICOM files contain not only the medical image but also important metadata. This metadata helps provide clinical context and is often used in preprocessing or filtering. Here are a few common examples:
#
# - `Patient ID ((0010,0020))`: A unique identifier for the patient the image belongs to.
# - `Modality ((0008,0060))`: The type of imaging device used (e.g., X-ray, CT, MRI).
# - `Study Date ((0008,0020))`: The date when the imaging study was performed.
#
# Reference: Bidgood, W. D., Jr, Horii, S. C., Prior, F. W., & Van Syckle, D. E. (1997). Understanding and using DICOM, the data interchange standard for biomedical imaging. Journal of the American Medical Informatics Association : JAMIA, 4(3), 199–212. https://doi.org/10.1136/jamia.1997.0040199

# %%
'''Now let us further explore the dataset.'''

# Number of total images
print(f"Total images: {len(df)}")

# Unique patients
print(f"Unique patients: {df['subject_id'].nunique()}")

# Unique studies
print(f"Unique studies: {df['study_id'].nunique()}")

# Number of images per patient
images_per_patient = df.groupby('subject_id')['dicom_id'].count()
print(f"Images per patient (min/max): {images_per_patient.min()} / {images_per_patient.max()}")
# Out:
# Total images: 600
# Unique patients: 523
# Unique studies: 583
# Images per patient (min/max): 1 / 2

# %%
df.groupby("edema_severity").apply(lambda x : print(len(x)))
# Out:
# 257
# 134
# 152
# 57
# /tmp/ipython-input-44-2350139873.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby("edema_severity").apply(lambda x : print(len(x)))
# Empty DataFrame
# Columns: []
# Index: []

# %%
'''Is our dataset balanced?'''

# Value counts and bar plot
severity_counts = df['edema_severity'].value_counts().sort_index()
severity_counts.plot(kind='bar', title='Edema Severity Distribution')
plt.xlabel('Edema Severity')
plt.ylabel('Number of Images')
plt.show()

# %% [markdown]
# 🎯  ***Food for Thought***
#
# What is the effect of class imbalance on training models? What ways can we implement to control it?

# %%
''' Check for missing values and duplicates '''

# Check for missing values
print("Missing values per column:\n", df.isnull().sum())

# Check for duplicate images
print("Duplicate dicom_ids:", df['dicom_id'].duplicated().sum())
# Out:
# Missing values per column:
#  subject_id        0
# study_id          0
# dicom_id          0
# edema_severity    0
# fold              0
# dtype: int64
# Duplicate dicom_ids: 0

# %% [markdown]
# 🎯  ***Food for Thought***
# - Why is it important to check how many patients vs. images we have?
# - If one patient has multiple images with different severity scores, what does that mean clinically? How would you use it for training?
# - What problems can arise from ignoring the patient-level grouping?

# %% [markdown]
# ## Task 2: Visual Inspection and Raw Image Loading

# %%
#Read DICOM Image

def read_dicom_image(row, image_folder ='/content/mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school'):
    """Read a DICOM image and return the pixel array."""
    patient_id = f"p{row['subject_id']}"
    study_id = f"s{row['study_id']}"
    #first two digits of the patient_id
    patient_folder = f"p{str(row['subject_id'])[:2]}"

    dicom_path = os.path.join(image_folder, patient_folder, patient_id, study_id, f"{row['dicom_id']}.dcm")
    ds = pydicom.dcmread(dicom_path)
    return ds

# %%
read_dicom_image()

# %%
# Select a sample of 2 images per edema severity class
samples = df.groupby('edema_severity').apply(lambda x: x.sample(2, random_state=42)).reset_index(drop=True)
samples
# Out:
# /tmp/ipython-input-11-859631269.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   samples = df.groupby('edema_severity').apply(lambda x: x.sample(2, random_state=42)).reset_index(drop=True)
#    subject_id  study_id                                      dicom_id  \
# 0    19931942  58636003  398465df-9e296e04-30c90ec7-afaba643-34be5488
# 1    10761861  53507372  024760d7-a52289bb-3aa7d8d5-7561ec33-5af99870
# 2    11625397  51233665  a929fdc2-9487ef9e-73e0d9da-4c493d0e-efacf336
# 3    16409112  57225097  ae1cb80d-a466d5e7-effab4a8-b36272e6-f6cd8d01
# 4    15812823  51070607  92235d79-3bb8a378-f503c66c-9b8c3d7a-c7d42926
# 5    11615169  55227980  a38dabe4-ab617bed-e49edcd6-0f0a722f-2dc71e68
# 6    10253803  55814412  63bb5bfa-88f93af9-b9d2e5d1-836e6797-aa7881af
# 7    12152816  57441659  9e560382-436cf924-43f75054-3c66e1bc-b8a3f06e
#
#    edema_severity  fold
# 0               0     5
# 1               0     5
# 2               1     3
# 3               1     3
# 4               2  TEST
# 5               2     1
# 6               3     1
# 7               3     2

# %%
# Set path to image folder
image_folder = '/content/mimic-cxr-subset-summer-school/mimic-cxr-subset-summer-school/' ##CHANGE THIS TO YOUR LOCAL PATH IF NECESSARY

# Plot samples
plt.figure(figsize=(12, 8))

for idx, row in samples.iterrows():
    ds = read_dicom_image(row, image_folder)
    img = ds.pixel_array

    plt.subplot(2, 4, idx + 1)
    plt.imshow(img, cmap='gray')
    plt.title(f"Severity: {row['edema_severity']}")
    plt.axis('off')

plt.suptitle("Sample CXR Images by Edema Severity", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# Now, let us explore the **pixel intensities**!
#
# Pixel intensities represent the brightness values in a medical image, where each number corresponds to how much radiation passed through the body at that point. Checking pixel intensities helps us understand image contrast, detect outliers, and decide on normalization or clipping strategies before training a model.

# %%
plt.figure(figsize=(12, 6))

for i, row in samples.iterrows():

    ds = read_dicom_image(row, image_folder)
    img = ds.pixel_array.astype(np.float32)

    plt.subplot(2, 4, i + 1)
    plt.hist(img.ravel(), bins=100, color='steelblue')
    plt.title(f"Severity {row['edema_severity']}")
    plt.xlabel("Pixel Intensity")
    plt.ylabel("Frequency")

    if i >= 7:
        break  # Only show 8 samples max

plt.tight_layout()
plt.show()

# %% [markdown]
# Do you see how the pixel intensity distributions vary across different edema severity classes? This can help us understand how edema severity might affect the pixel intensity distribution in CXR images.
#
# Now, we should apply clipping to these images! Clipping is used to remove extreme pixel values that may be due to noise or artifacts and can negatively affect model training. We can perform clipping using either a percentile-based approach (e.g., keeping the central 99% of values) or by setting a fixed intensity range.

# %%
def clip_percentile(image, lower=0.5, upper=99):
    image = image.astype(np.float32)
    low_val = np.percentile(image, lower)
    high_val = np.percentile(image, upper)
    print(f"Clipping range: {low_val:.2f} to {high_val:.2f}")
    return np.clip(image, low_val, high_val)



def clip_fixed(image, min_val=0, max_val=3000):
    return np.clip(image, min_val, max_val)

# %%
'''Now, let's visualize the pixel intensity distributions before and after clipping. We will use the first 4 samples from our previous selection.'''

plt.figure(figsize=(12, 6))

for i, row in samples.head(4).iterrows():
    ds = read_dicom_image(row, image_folder)
    img = ds.pixel_array.astype(np.float32)

    # Apply percentile clipping
    clipped = clip_percentile(img)

    # Plot histograms
    plt.subplot(2, 4, i + 1)
    plt.hist(img.ravel(), bins=100)
    plt.title("Original Histogram")

    plt.subplot(2, 4, i + 5)
    plt.hist(clipped.ravel(), bins=100)
    plt.title("Clipped Histogram")

plt.tight_layout()
plt.show()
# Out:
# Clipping range: 0.00 to 3825.00
# Clipping range: 0.00 to 3590.00
# Clipping range: 0.00 to 3579.00
# Clipping range: 0.00 to 3649.00

# %%
'''Let's visualize the original and clipped images side-by-side for the first sample.'''

row = samples.iloc[0]
ds = read_dicom_image(row, image_folder)
img = ds.pixel_array

clipped = clip_percentile(img, lower=0.5, upper=90)

# Plot side-by-side
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title("Original Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(clipped, cmap='gray')
plt.title("Clipped Image")
plt.axis('off')
plt.show()
# Out:
# Clipping range: 0.00 to 3728.00

# %% [markdown]
# After clipping, we will rescale to a unit range. Rescaling to a unit range (e.g., [0, 1]) ensures that all images have consistent intensity scales, which helps models learn more effectively and speeds up convergence. It also prevents large pixel values from dominating gradients during training.
#
# Common rescaling ranges include:
#
# - [0, 1] — standard for most deep learning models using normalized inputs.
# - [-1, 1] — often used when inputs are centered, especially with tanh activations.
# - [0, 255] — used when saving or displaying images in 8-bit format.

# %%
'''Now, let us rescale the image to a unit range. The following function rescales the image according to the minimum and maximum pixel values.
If the image has no variation (i.e., all pixels have the same value), it returns an array of zeros.'''

def rescale_to_unit_range(image):
    min_val = np.min(image)
    max_val = np.max(image)
    if max_val - min_val == 0:
        return np.zeros_like(image)
    return (image - min_val) / (max_val - min_val)

# %%
'''Now, let's visualize the original, clipped, and rescaled images side-by-side for the first sample.'''

row = samples.iloc[0]
ds = read_dicom_image(row, image_folder)
img = ds.pixel_array.astype(np.float32)

# Apply clipping and rescaling
clipped = clip_percentile(img)
rescaled = rescale_to_unit_range(clipped)

# Plot
plt.figure(figsize=(15, 4))

plt.subplot(1, 3, 1)
plt.imshow(img, cmap='gray')
plt.title("Original")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(clipped, cmap='gray')
plt.title("Clipped")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(rescaled, cmap='gray')
plt.title("Clipped + Rescaled [0, 1]")
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Clipping range: 0.00 to 3825.00

# %% [markdown]
# 🎯  ***Food for Thought***
#
# - What happens to image contrast after clipping?
# - Why might we prefer percentile clipping over fixed thresholds?
# - How can clipping improve training stability?

# %% [markdown]
# ## Task 3: Resize and Normalize CXR Images

# %% [markdown]
# Prior to feeding images to machine learning models, they should be resized. Resizing ensures all images have the same shape, and since ML models expect fixed-size inputs, think of it like making sure every puzzle piece fits into the model’s input slot! Without resizing, the model simply would not know how to process the image.

# %%
import cv2

def preprocess_image(image, size=(224, 224), clip=True, rescale=True):
    image = image.astype(np.float32)

    if clip:
        image = clip_percentile(image)

    if rescale:
        image = rescale_to_unit_range(image)

    # Resize to target size using OpenCV
    resized = cv2.resize(image, size, interpolation=cv2.INTER_AREA)

    return resized

# %%
plt.figure(figsize=(12, 8))

for i, row in samples.head(8).iterrows():
    ds = read_dicom_image(row, image_folder)
    img = ds.pixel_array

    processed = preprocess_image(img)

    plt.subplot(2, 4, i + 1)
    plt.imshow(processed, cmap='gray')
    plt.title(f"Severity {row['edema_severity']}")
    plt.axis('off')

plt.suptitle("Resized & Normalized CXR Images (224x224)", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Clipping range: 0.00 to 3825.00
# Clipping range: 0.00 to 3590.00
# Clipping range: 0.00 to 3579.00
# Clipping range: 0.00 to 3649.00
# Clipping range: 0.00 to 3179.00
# Clipping range: 0.00 to 3805.00
# Clipping range: 0.00 to 3810.00
# Clipping range: 0.00 to 3386.00

# %% [markdown]
# 🎯  ***Food for Thought***
#
# - Why do we need all images to be the same size?
# - What is the tradeoff between 224×224 vs. 512×512?
# - Why might we normalize to [0, 1] instead of standardizing?

# %%
#Optional: Convert image to tensor for PyTorch
import torch

def image_to_tensor(image):
    # Add channel dimension: (1, H, W)
    return torch.tensor(image).unsqueeze(0).float()

# %% [markdown]
# ## Task 4: Data Augmentation for CXR images
#
# Next, we move to data augmentations. We augment data to help the model see different versions of the same image, like flipping, rotating, or changing brightness — so it learns to focus on the important patterns, not just the exact layout. This makes the model more robust and improves its ability to generalize to new, unseen data.

# %%
# Define training augmentations
aug_transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.Rotate(limit=10, p=0.5),  # ±10 degrees
    A.RandomBrightnessContrast(p=0.5),
    A.GaussianBlur(blur_limit=3, p=0.4),
])

# %%
def augment_and_plot(image, transform, n=5):
    plt.figure(figsize=(15, 3))
    for i in range(n):
        augmented = transform(image=image)['image']
        plt.subplot(1, n, i + 1)
        plt.imshow(augmented, cmap='gray')
        plt.axis('off')
        plt.title(f'Augment {i+1}')
    plt.tight_layout()
    plt.show()

# Load and preprocess one image
row = samples.iloc[0]
ds = read_dicom_image(row, image_folder)
img = ds.pixel_array

preprocessed = preprocess_image(img)  # from Task 3

# Convert to 8-bit image for augmentation (albumentations expects HxW uint8)
image_uint8 = (preprocessed * 255).astype('uint8')

augment_and_plot(image_uint8, aug_transform, n=5)
# Out:
# Clipping range: 0.00 to 3825.00

# %% [markdown]
# 🎯  ***Food for Thought***
#
# - Which augmentations are realistic for CXR? Which ones might be harmful?
# - Why don’t we apply vertical flip?
# - When should we apply augmentations (training vs. validation)?

# %% [markdown]
# ## Task 5: Building a Pytorch Dataset for CXR Edema Classification
#
# Now that we have all the necessary steps, let us build a dataset class!
#
# We build a custom Dataset class in PyTorch to organize how images and labels are loaded, preprocessed, and fed into the model. It gives us full control over loading DICOM files, applying transforms, and ensuring the data is ready for training in batches. If you are not familiar with PyTorch, it is a popular deep learning library that lets you build and train neural networks with flexibility and ease.

# %%
import torch
from torch.utils.data import Dataset
import pydicom
import cv2
import os

class CXRDataset(Dataset):
    def __init__(self, df, image_folder, transform=None, image_size=(224, 224), training=True):
        self.df = df.reset_index(drop=True)
        self.folder = image_folder
        self.transform = transform
        self.image_size = image_size
        self.training = training

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        patient_id = f"p{row['subject_id']}"
        study_id = f"s{row['study_id']}"
        #first two digits of the patient_id
        patient_folder = f"p{str(row['subject_id'])[:2]}"
        dicom_path = os.path.join(self.folder, patient_folder, patient_id, study_id, f"{row['dicom_id']}.dcm")
        ds = pydicom.dcmread(dicom_path)
        image = ds.pixel_array.astype(np.float32)

        # Preprocessing: clip, rescale, resize
        image = clip_percentile(image)
        image = rescale_to_unit_range(image)
        image = cv2.resize(image, self.image_size, interpolation=cv2.INTER_AREA)

        # Convert to uint8 for albumentations
        if self.transform:
            image = (image * 255).astype('uint8')
            image = self.transform(image=image)['image']  # transform returns dict
            image = torch.tensor(image).unsqueeze(0).float() / 255.0
            image = image.float() / 255.0  # Back to float in [0, 1]
        else:
            image = torch.tensor(image).unsqueeze(0).float()  # (1, H, W)

        label = torch.tensor(row['edema_severity'], dtype=torch.long)

        return image, label

# %%
from sklearn.model_selection import GroupShuffleSplit

'''GroupShuffleSplit is used to ensure that images from the same patient are not split between training and validation sets.'''

gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_idx, val_idx = next(gss.split(df, groups=df['subject_id']))

df_train = df.iloc[train_idx]
df_val = df.iloc[val_idx]

# %%
df_train
# Out:
#      subject_id  study_id                                      dicom_id  \
# 1      10130348  57511959  c23640ba-9a3fc83e-df6f06f2-9244d819-275ef0b3
# 2      10154271  51768020  c92820ab-86ca072a-cb979fed-e8a9b8f0-2e1b4472
# 3      10170334  50465091  41eb4980-c532d3f5-25e1b923-6696c9fa-b9e26262
# 6      10251182  53163573  c96a3609-3ccd0269-9d55c79c-b794bca9-7bb6715f
# 7      10253803  55814412  63bb5bfa-88f93af9-b9d2e5d1-836e6797-aa7881af
# ..          ...       ...                                           ...
# 593    12764402  54064800  081e279e-b0923a53-2c04878a-f759b071-2c0e1da9
# 594    12764402  54064800  8f52c156-7407bf97-ec66fc0e-141c5c9a-e4e06074
# 595    12995867  54694807  95adeb4b-e940fba6-458c5da2-3c3183f0-5ee010b5
# 596    13005295  52445498  3c5a1051-8b9abbe3-dba58167-8fc77605-0df66051
# 597    13005295  57420765  3ead1149-7aa92d09-32989180-022396a2-f9a48f2c
#
#      edema_severity  fold
# 1                 0     1
# 2                 1     2
# 3                 0     3
# 6                 0     4
# 7                 3     1
# ..              ...   ...
# 593               0  TEST
# 594               0  TEST
# 595               0     2
# 596               0     3
# 597               0     3
#
# [474 rows x 5 columns]

# %%
from torch.utils.data import DataLoader

'''Now we will create DataLoaders for training and validation datasets. DataLoaders are used to efficiently load data in batches during
training and validation.'''

# Use the same transform from Task 4
train_dataset = CXRDataset(df_train, image_folder, transform=aug_transform, training=True)
val_dataset = CXRDataset(df_val, image_folder, transform=None, training=False)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False)

# %%
'''Let's visualize some images from the training DataLoader to ensure everything is working correctly.'''

images, labels = next(iter(train_loader))

plt.figure(figsize=(12, 6))
for i in range(len(images)):
    plt.subplot(2, 4, i+1)
    plt.imshow(images[i][0], cmap='gray')
    plt.title(f"Label: {labels[i].item()}")
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Clipping range: 0.00 to 3707.00
# Clipping range: 0.00 to 3316.00
# Clipping range: 0.00 to 3579.00
# Clipping range: 108.00 to 3910.00
# Clipping range: 0.00 to 3515.00
# Clipping range: 0.00 to 3884.00
# Clipping range: 0.00 to 3706.00
# Clipping range: 86.00 to 3895.00

# %% [markdown]
# 🎯  ***Food for Thought***
#
# - Why is patient-level splitting important in medical data?
# - What does the Dataset return? How does it integrate with models?
# - What happens if we skip normalization or augmentation?

# %% [markdown]
# ## Task 6: Traditional Feature Extraction from CXR Images
#
# **Traditional feature extraction methods**, like ORB and GLCM, are used to capture patterns, textures, and shapes in medical images using hand-crafted techniques. They were widely used before deep learning and are still helpful when working with small datasets or when interpretability is important.
#
# Deep learning models now automatically learn powerful features directly from images, often outperforming traditional methods , but handcrafted features can still be useful in hybrid systems or for validation.
#
# **Now, let us start with the ORB method!**
#
# ORB (Oriented FAST and Rotated BRIEF) is a feature extraction method used to detect keypoints in an image (areas with sharp changes like edges or corners) and describe them with compact numeric vectors. These features can be used to match similar regions across images or recognize patterns. ORB is fast, rotation-invariant, and widely used in traditional computer vision tasks like image matching or retrieval.

# %%
import cv2

def show_orb_keypoints(image, title='ORB Keypoints'):
    orb = cv2.ORB_create(nfeatures=200)
    keypoints = orb.detect(image, None)
    keypoints, descriptors = orb.compute(image, keypoints)

    img_kp = cv2.drawKeypoints(image, keypoints, None, flags=cv2.DrawMatchesFlags_DRAW_RICH_KEYPOINTS)

    plt.figure(figsize=(6, 6))
    plt.imshow(img_kp, cmap='gray')
    plt.title(title)
    plt.axis('off')
    plt.show()

    return descriptors

# %%
# Load and preprocess one image
row = samples.iloc[0]
ds = read_dicom_image(row, image_folder)
img = ds.pixel_array
img = preprocess_image(img)
img_uint8 = (img * 255).astype('uint8')

descriptors = show_orb_keypoints(img_uint8)
print(f"ORB descriptor shape: {descriptors.shape if descriptors is not None else 'None'}")
# Out:
# Clipping range: 0.00 to 3825.00
# ORB descriptor shape: (92, 32)

# %% [markdown]
# **Then, let us move to GLCM!**
#
# GLCM (Gray Level Co-occurrence Matrix) is a texture analysis method that calculates how often pairs of pixel intensities occur in specific spatial relationships. From this matrix, we can extract texture features such as contrast, energy, homogeneity, and correlation. GLCM is particularly useful in medical imaging to capture tissue patterns and subtle differences in image texture.

# %%
from skimage.feature import graycomatrix, graycoprops

def extract_glcm_features(image, distances=[1], angles=[0], levels=256):
    image = (image * 255).astype('uint8')  # GLCM expects uint8
    glcm = graycomatrix(image, distances=distances, angles=angles, levels=levels, symmetric=True, normed=True)

    features = {
        'contrast': graycoprops(glcm, 'contrast')[0, 0],
        'homogeneity': graycoprops(glcm, 'homogeneity')[0, 0],
        'energy': graycoprops(glcm, 'energy')[0, 0],
        'correlation': graycoprops(glcm, 'correlation')[0, 0],
    }
    return features

glcm_feats = extract_glcm_features(img)
print("GLCM Texture Features:")
for k, v in glcm_feats.items():
    print(f"  {k}: {v:.4f}")
# Out:
# GLCM Texture Features:
#   contrast: 156.2035
#   homogeneity: 0.4557
#   energy: 0.0443
#   correlation: 0.9855

# %% [markdown]
# 🎯  ***Food for Thought***
#
# - What do these features capture compared to deep features?
# - Would these be useful in low-data regimes?
# - How do we combine them with models (e.g., random forest, or hybrid CNN + GLCM)?

# %% [markdown]
# ### Lung Region of Interest (Lung ROI)

# %% [markdown]
# The purpose of extracting a lung ROI (region of interest) is to focus the model only on the parts of the image that matter most, the lungs, while reducing noise from irrelevant areas like the ribs or background. This can help the model learn more efficiently and improve performance.
#
# To give a bit more intuition, imagine you are trying to read a map of an entire country, but you are only interested in one small city. Looking at everything at once can be overwhelming, and the details you care about might get lost in all the noise. That’s exactly what happens with medical images.
#
# In chest X-rays, for example, we often want to focus only on the lungs, because that’s where signs of disease usually appear. If we let the model look at the entire image, including the spine, ribs, or labels in the corners, it might get distracted and learn the wrong things.
#
# So instead of giving it the full map, we crop out just the important part, **the Region of Interest (ROI)**, so the model can concentrate, learn faster, and perform better.
#
#
# There are many automatic ways to extract ROIs, from rule-based methods to advanced deep learning models that can segment organs with high precision. But before jumping into complex tools, it's important to understand the basics.
#
# In this notebook, we’ll start by exploring a **simple cropping approach** to isolate the lungs. Once you see how that works, you will be ready to experiment with more powerful deep learning-based methods later on!

# %%
def center_crop_lung_heuristic(image, crop_ratio=0.1):
    h, w = image.shape
    top = int(h * crop_ratio)
    bottom = int(h * (1 - crop_ratio))
    left = int(w * crop_ratio)
    right = int(w * (1 - crop_ratio))
    return image[top:bottom, left:right]

# %%
# Load and preprocess image
img = ds.pixel_array.astype(np.float32) #using the same ds from previous cell
img = preprocess_image(img)  # clip + normalize + resize to e.g., 512x512
img_uint8 = (img * 255).astype('uint8')

roi = center_crop_lung_heuristic(img_uint8)

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.imshow(img_uint8, cmap='gray')
plt.title("Original")

plt.subplot(1, 2, 2)
plt.imshow(roi, cmap='gray')
plt.title("Lung ROI")

plt.tight_layout()
plt.show()

# %% [markdown]
# Optional Extension:
# Use a pretrained lung segmentation model (like from MONAI, TorchXRayVision, or pydicom-seg tools).
